# %%
import sys
print(sys.executable)
# !{sys.executable} -m pip install -r requirements.txt
# Out:
# /Users/coricampbell/Documents/hockey_analyses/venv/bin/python
# ...

# %%
# =============================
# Reqs/setup
# =============================

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import requests
import json
from datetime import datetime

from pathlib import Path

pd.set_option("display.max_columns", 100)
pd.set_option("display.float_format", lambda x: f"{x:.3f}")

# %%
# NHL API URL
BASE_URL = "https://api-web.nhle.com/v1"

# Test connection
response = requests.get(f"{BASE_URL}/standings/now")
print(f"Status Code: {response.status_code}")
print("API is working!" if response.status_code == 200 else "API error")
# Out:
# Status Code: 200
# API is working!

# %%
# =============================
# Load Data
# =============================

# Game ID: 2023020204
# Format: SSSSTTGGGG where SSSS=season, TT=game type (02=regular), GGGG=game number
game_id = 2023020204

# Fetch play-by-play data
pbp_data = get_nhl_data(f'/gamecenter/{game_id}/play-by-play')

# Explore the structure
print("Top-level keys:", list(pbp_data.keys()))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 10
#       7 game_id = 2023020204
#       9 # Fetch play-by-play data
# ---> 10 pbp_data = get_nhl_data(f'/gamecenter/{game_id}/play-by-play')
#      12 # Explore the structure
#      13 print("Top-level keys:", list(pbp_data.keys()))
#
# NameError: name 'get_nhl_data' is not defined
